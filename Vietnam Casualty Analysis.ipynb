# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("VietnamCasualties.csv")

# %%
data.head()
# Out:
#   SERVICE_TYPE SERVICE_CODE        ENROLLMENT        BRANCH  RANK PAY_GRADE  \
# 0            Y            S  SELECTED SERVICE          ARMY   SP4       E04
# 1            Y            S  SELECTED SERVICE          ARMY   SGT       E05
# 2            R            K  ACTIVE - REGULAR     AIR FORCE   A1C       E03
# 3            Y            S  SELECTED SERVICE  MARINE CORPS  LCPL       E03
# 4            Y            S  SELECTED SERVICE          ARMY   SP4       E04
#
#       POSITION  BIRTH_YEAR SEX      HOME_CITY      ...      DEPLOYMENT_ZONE  \
# 0  INFANTRYMAN    19450329   M       SISSETON      ...                   M2
# 1  INFANTRYMAN    19450511   M        HOUSTON      ...                   M3
# 2          NaN    19510823   M       MOORHEAD      ...                   M2
# 3     RIFLEMAN    19440608   M           KENT      ...                   M1
# 4  INFANTRYMAN    19481212   M  FORGE VILLAGE      ...                   M2
#
#   DEPLOYMENT_COUNTRY_CODE DEPLOYMENT_COUNTRY                    DIVISION  \
# 0                      VS      SOUTH VIETNAM  D CO 3 BN 12 INF 4 INF DIV
# 1                      VS      SOUTH VIETNAM         1 CAV DIV AIRMOBILE
# 2                      VS      SOUTH VIETNAM                         NaN
# 3                      VS      SOUTH VIETNAM                         NaN
# 4                      VS      SOUTH VIETNAM               1 FIELD FORCE
#
#   FATALITY_YEAR FATALITY_DATE HOSTILITY_CONDITIONS          FATALITY  \
# 0          1968      19680501                    H  KILLED IN ACTION
# 1          1970      19700301                    H  KILLED IN ACTION
# 2          1970      19700801                   NH          ACCIDENT
# 3          1966      19661201                    H    DIED OF WOUNDS
# 4          1970      19700501                    H  KILLED IN ACTION
#
#                 FATALITY_2 BURIAL_STATUS
# 0          SMALL ARMS FIRE             Y
# 1  ARTILLERY/MORTAR/ROCKET             Y
# 2           OTHER ACCIDENT             Y
# 3         EXPLOSIVE DEVICE             Y
# 4                  GRENADE             Y
#
# [5 rows x 31 columns]

# %%
# variables
ethnicity = data["ETHNICITY"]
serviceType = data["ENROLLMENT"]
branch = data["BRANCH"]
fatality = data["FATALITY"]
city = data["HOME_CITY"]
religion = data["RELIGION"]
yearOfFatality = data["FATALITY_YEAR"]
causeOfDeath = data["FATALITY_2"]
rank = data["RANK"]

# %%
# City data
city.describe()
# Out:
# count        58098
# unique        9441
# top       NEW YORK
# freq          1370
# Name: HOME_CITY, dtype: object

# %%
# Casualties per city
city.value_counts()
# Out:
# NEW YORK           1370
# CHICAGO             955
# PHILADELPHIA        623
# LOS ANGELES         539
# DETROIT             526
# BALTIMORE           418
# COLUMBUS            380
# HOUSTON             361
# ST LOUIS            296
# WASHINGTON          289
# SAN ANTONIO         288
# DALLAS              278
# CLEVELAND           265
# PITTSBURGH          256
# JACKSONVILLE        238
# SEATTLE             238
# MEMPHIS             233
# CINCINNATI          227
# PORTLAND            222
# PHOENIX             212
# KANSAS CITY         205
# MILWAUKEE           204
# INDIANAPOLIS        204
# RICHMOND            198
# SPRINGFIELD         198
# LOUISVILLE          196
# MINNEAPOLIS         193
# ATLANTA             192
# MIAMI               188
# DENVER              185
#                    ...
# COEYMANS HOLLOW       1
# NEW LIBERTY           1
# SANTUIT               1
# RUSSELLTON            1
# EGLIN AFB             1
# CAVE SPRINGS          1
# SMICKSBURG            1
# CLEAR SPRING          1
# WILMERDING            1
# CANAL POINT           1
# BEAVER DAMS           1
# RINGOES               1
# SECAUCUS              1
# CEREDO                1
# MONTEAGLE             1
# BRADDOCK              1
# NICOMA PARK           1
# FT WINGATE            1
# DOLA                  1
# SHERBURN              1
# ALKOL                 1
# ALLPORT               1
# GREECE                1
# ZIMMERMAN             1
# BRACKENRIDGE          1
# ZIRCONIA              1
# SOUTH HADLEY          1
# LEONARDTOWN           1
# HANNA                 1
# FARNER                1
# Name: HOME_CITY, Length: 9441, dtype: int64

# %%
data["CASUALTIES_PER_CITY"] = city.value_counts()
data["CASUALTIES_PER_CITY"]
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
# 5       NaN
# 6       NaN
# 7       NaN
# 8       NaN
# 9       NaN
# 10      NaN
# 11      NaN
# 12      NaN
# 13      NaN
# 14      NaN
# 15      NaN
# 16      NaN
# 17      NaN
# 18      NaN
# 19      NaN
# 20      NaN
# 21      NaN
# 22      NaN
# 23      NaN
# 24      NaN
# 25      NaN
# 26      NaN
# 27      NaN
# 28      NaN
# 29      NaN
#          ..
# 58190   NaN
# 58191   NaN
# 58192   NaN
# 58193   NaN
# 58194   NaN
# 58195   NaN
# 58196   NaN
# 58197   NaN
# 58198   NaN
# 58199   NaN
# 58200   NaN
# 58201   NaN
# 58202   NaN
# 58203   NaN
# 58204   NaN
# 58205   NaN
# 58206   NaN
# 58207   NaN
# 58208   NaN
# 58209   NaN
# 58210   NaN
# 58211   NaN
# 58212   NaN
# 58213   NaN
# 58214   NaN
# 58215   NaN
# 58216   NaN
# 58217   NaN
# 58218   NaN
# 58219   NaN
# Name: CASUALTIES_PER_CITY, Length: 58220, dtype: float64

# %%
# cityPlot = plt.plot(city)
# cityPlot
# concentratedCasualties = data[data["HOME_CITY"] > 200]
concentrated = city.value_counts()
# concentratedCasualties = concentrated > 150
concentratedCasualties = (data["CASUALTIES_PER_CITY"] > 200)
concentratedCasualties
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
# 5        False
# 6        False
# 7        False
# 8        False
# 9        False
# 10       False
# 11       False
# 12       False
# 13       False
# 14       False
# 15       False
# 16       False
# 17       False
# 18       False
# 19       False
# 20       False
# 21       False
# 22       False
# 23       False
# 24       False
# 25       False
# 26       False
# 27       False
# 28       False
# 29       False
#          ...
# 58190    False
# 58191    False
# 58192    False
# 58193    False
# 58194    False
# 58195    False
# 58196    False
# 58197    False
# 58198    False
# 58199    False
# 58200    False
# 58201    False
# 58202    False
# 58203    False
# 58204    False
# 58205    False
# 58206    False
# 58207    False
# 58208    False
# 58209    False
# 58210    False
# 58211    False
# 58212    False
# 58213    False
# 58214    False
# 58215    False
# 58216    False
# 58217    False
# 58218    False
# 58219    False
# Name: CASUALTIES_PER_CITY, Length: 58220, dtype: bool

# %%
# White casualty count
whiteCasualty = data[ethnicity == "WHITE"]
whiteCasualty["ETHNICITY"].count()
# Out:
# 50155

# %%
# All data for casualties from New York City
# nyCasusalty = city["NEW YORK"]
# nyCasualty = data[data["HOME_CITY"] == "NEW YORK"]
nyCasualty = data[city == "NEW YORK"]
nyCasualty
# Out:
#       SERVICE_TYPE SERVICE_CODE              ENROLLMENT        BRANCH  RANK  \
# 13               R            K        ACTIVE - REGULAR          ARMY   SGT
# 36               Y            S        SELECTED SERVICE          ARMY   CPL
# 74               R            K        ACTIVE - REGULAR          ARMY   CPL
# 75               Y            S        SELECTED SERVICE          ARMY   SP4
# 128              Y            S        SELECTED SERVICE          ARMY   PFC
# 130              R            K        ACTIVE - REGULAR          ARMY   SP4
# 159              R            K        ACTIVE - REGULAR          ARMY   PFC
# 327              R            K        ACTIVE - REGULAR  MARINE CORPS   PFC
# 334              Y            S        SELECTED SERVICE          ARMY   SP4
# 363              R            K        ACTIVE - REGULAR  MARINE CORPS   PVT
# 420              Y            S        SELECTED SERVICE          ARMY   PFC
# 487              R            K        ACTIVE - REGULAR  MARINE CORPS   SGT
# 588              R            K        ACTIVE - REGULAR          ARMY   SGT
# 591              R            K        ACTIVE - REGULAR          ARMY   SP4
# 593              R            K        ACTIVE - REGULAR          ARMY   SP4
# 611              Y            S        SELECTED SERVICE          ARMY   PFC
# 613              Y            S        SELECTED SERVICE          ARMY   PFC
# 615              Y            S        SELECTED SERVICE          ARMY   PFC
# 619              V            L  ACTIVE - GUARD/RESERVE          ARMY   WO1
# 663              Y            S        SELECTED SERVICE          ARMY   PFC
# 792              Y            S        SELECTED SERVICE          ARMY   SP4
# 827              R            K        ACTIVE - REGULAR          ARMY   PFC
# 831              R            K        ACTIVE - REGULAR          ARMY   SGT
# 864              Y            S        SELECTED SERVICE          ARMY   PFC
# 906              R            K        ACTIVE - REGULAR          ARMY   SP5
# 966              R            K        ACTIVE - REGULAR          ARMY   SGT
# 1003             R            K        ACTIVE - REGULAR          ARMY   PFC
# 1020             R            K        ACTIVE - REGULAR     AIR FORCE  TSGT
# 1053             Y            S        SELECTED SERVICE          ARMY   PFC
# 1082             Y            S        SELECTED SERVICE          ARMY   PFC
# ...            ...          ...                     ...           ...   ...
# 56308            Y            S        SELECTED SERVICE          ARMY   PFC
# 56334            R            K        ACTIVE - REGULAR          ARMY   SP4
# 56420            Y            S        SELECTED SERVICE          ARMY   PFC
# 56450            Y            S        SELECTED SERVICE          ARMY   PFC
# 56476            Y            S        SELECTED SERVICE          ARMY   SP4
# 56530            R            K        ACTIVE - REGULAR          ARMY   PFC
# 56537            R            K        ACTIVE - REGULAR  MARINE CORPS   PFC
# 56547            R            K        ACTIVE - REGULAR          ARMY   SP4
# 56550            Y            S        SELECTED SERVICE          ARMY   SP4
# 56709            R            K        ACTIVE - REGULAR          ARMY   PFC
# 56777            R            K        ACTIVE - REGULAR          ARMY   PFC
# 56803            R            K        ACTIVE - REGULAR     AIR FORCE  SSGT
# 56881            R            K        ACTIVE - REGULAR          ARMY   SP4
# 57017            V            L  ACTIVE - GUARD/RESERVE     AIR FORCE   COL
# 57040            R            K        ACTIVE - REGULAR          ARMY   SSG
# 57086            R            K        ACTIVE - REGULAR          ARMY   SGM
# 57217            Y            S        SELECTED SERVICE          ARMY   CPL
# 57308            Y            S        SELECTED SERVICE          ARMY   SP4
# 57588            R            K        ACTIVE - REGULAR  MARINE CORPS   CPL
# 57636            R            K        ACTIVE - REGULAR          ARMY   PFC
# 57680            R            K        ACTIVE - REGULAR          ARMY   PFC
# 57689            R            K        ACTIVE - REGULAR          ARMY   SGT
# 57714            Y            S        SELECTED SERVICE          ARMY   SP4
# 57853            V            L  ACTIVE - GUARD/RESERVE          ARMY   1LT
# 57863            Y            S        SELECTED SERVICE          ARMY   SFC
# 58067            V            L  ACTIVE - GUARD/RESERVE          ARMY   2LT
# 58082            R            K        ACTIVE - REGULAR  MARINE CORPS   PFC
# 58141            R            K        ACTIVE - REGULAR          ARMY   SGT
# 58147            R            K        ACTIVE - REGULAR          ARMY   SFC
# 58159            V            L  ACTIVE - GUARD/RESERVE          NAVY  LTJG
#
#       PAY_GRADE                                           POSITION  \
# 13          E05                    CONSTRUCTION EQUIPMENT REPAIRER
# 36          E03                            FIXED STATION ATTENDANT
# 74          E03                 EXECUTIVE ADMINISTRATIVE ASSISTANT
# 75          E04                              FIELD ARTILLERY BASIC
# 128         E03                                        INFANTRYMAN
# 130         E04                                        INFANTRYMAN
# 159         E03                                        INFANTRYMAN
# 327         E02                                           RIFLEMAN
# 334         E04                                        INFANTRYMAN
# 363         E01                                           RIFLEMAN
# 420         E03                            FOOD SERVICE SPECIALIST
# 487         E05                                           RIFLEMAN
# 588         E05                   CANNON FIRE DIRECTION SPECIALIST
# 591         E04                                        INFANTRYMAN
# 593         E04                              FIELD ARTILLERY BASIC
# 611         E03                          INDIRECT FIRE INFANTRYMAN
# 613         E03                                        INFANTRYMAN
# 615         E03                                    MILITARY POLICE
# 619         W01  HELICOPTER PILOT, UTILITY AND LIGHT CARGO SING...
# 663         E03                                        INFANTRYMAN
# 792         E04             TELECOMMUNICATIONS OPERATOR-MAINTAINER
# 827         E03                                        INFANTRYMAN
# 831         E04                                        INFANTRYMAN
# 864         E03                                        INFANTRYMAN
# 906         E05                            FOOD SERVICE SPECIALIST
# 966         E05    INFANTRY OPERATIONS AND INTELLIGENCE SPECIALIST
# 1003        E03                                        INFANTRYMAN
# 1020        E06                                                NaN
# 1053        E03                                                NaN
# 1082        E03                                        INFANTRYMAN
# ...         ...                                                ...
# 56308       E03                            FOOD SERVICE SPECIALIST
# 56334       E04                                        INFANTRYMAN
# 56420       E03                                        INFANTRYMAN
# 56450       E03                                        INFANTRYMAN
# 56476       E04  FIELD COMMUNICATIONS ELECTRONICS EQUIPMENT MEC...
# 56530       E03                                        INFANTRYMAN
# 56537       E02                                         ASSAULTMAN
# 56547       E04                   OH-13/OH-23 HELICOPTER REPAIRMAN
# 56550       E04                                    COMBAT ENGINEER
# 56709       E03                             WIRE SYSTEMS INSTALLER
# 56777       E03                          INDIRECT FIRE INFANTRYMAN
# 56803       E05                                                NaN
# 56881       E04                          INDIRECT FIRE INFANTRYMAN
# 57017       O06                                              PILOT
# 57040       E06                                        INFANTRYMAN
# 57086       E09                           INFANTRY SENIOR SERGEANT
# 57217       E03                                        INFANTRYMAN
# 56450      SOUTH VIETNAM                       101 AIRBORNE DIV          1968
# 56476      SOUTH VIETNAM                 US ARMY REP OF VIETNAM          1971
# 56530      SOUTH VIETNAM                       173 AIRBORNE BDE          1965
# 56537      SOUTH VIETNAM                                    NaN          1967
# 56547      SOUTH VIETNAM                              1 AVN BDE          1966
# 56550      SOUTH VIETNAM                             25 INF DIV          1969
# 56709      SOUTH VIETNAM                       173 AIRBORNE BDE          1967
# 56777      SOUTH VIETNAM                       101 AIRBORNE DIV          1966
# 56803      SOUTH VIETNAM                                  13 AF          1969
# 56881      SOUTH VIETNAM                    1 CAV DIV AIRMOBILE          1966
# 57017               LAOS                                563 TFS          1965
# 57040      SOUTH VIETNAM                          MACV ADVISORS          1967
# 57086      SOUTH VIETNAM                         SPECIAL FORCES          1968
# 57217      SOUTH VIETNAM                              4 INF DIV          1968
# 57308      SOUTH VIETNAM                       11 LIGHT INF BDE          1968
# 57588      SOUTH VIETNAM                                    NaN          1968
# 57636      SOUTH VIETNAM                    1 CAV DIV AIRMOBILE          1968
# 57680      SOUTH VIETNAM                              4 INF DIV          1970
# 57689      SOUTH VIETNAM                    1 CAV DIV AIRMOBILE          1968
# 57714      SOUTH VIETNAM                              1 INF DIV          1967
# 57853      SOUTH VIETNAM                              4 INF DIV          1968
# 57863      SOUTH VIETNAM                             25 INF DIV          1968
# 58067      SOUTH VIETNAM                    1 CAV DIV AIRMOBILE          1966
# 58082      SOUTH VIETNAM                                    NaN          1968
# 58141      SOUTH VIETNAM                       173 AIRBORNE BDE          1968
# 58147      SOUTH VIETNAM                          MACV ADVISORS          1968
# 58159      SOUTH VIETNAM             VAW 11 USS ORISKANY CVA 34          1967
#
#       FATALITY_DATE HOSTILITY_CONDITIONS          FATALITY  \
# 13         19670401                   NH          ACCIDENT
# 36         19680101                    H  KILLED IN ACTION
# 74         19680501                    H  KILLED IN ACTION
# 75         19660801                   NH          ACCIDENT
# 128        19660801                    H  KILLED IN ACTION
# 130        19690201                    H  KILLED IN ACTION
# 159        19661001                    H  KILLED IN ACTION
# 327        19680801                    H  KILLED IN ACTION
# 334        19690101                    H  KILLED IN ACTION
# 363        19690901                   NH          ACCIDENT
# 420        19720401                   NH          ACCIDENT
# 487        19670601                    H    DIED OF WOUNDS
# 588        19700301                   NH          ACCIDENT
# 591        19660301                    H  KILLED IN ACTION
# 593        19690301                   NH    SELF-INFLICTED
# 611        19680901                    H  KILLED IN ACTION
# 613        19660601                    H  KILLED IN ACTION
# 615        19680901                    H  KILLED IN ACTION
# 619        19690801                   NH          ACCIDENT
# 663        19710301                    H  KILLED IN ACTION
# 792        19680501                    H  KILLED IN ACTION
# 827        19660601                    H  KILLED IN ACTION
# 831        19680501                    H  KILLED IN ACTION
# 864        19661201                    H  KILLED IN ACTION
# 906        19681001                   NH    SELF-INFLICTED
# 966        19661001                    H  KILLED IN ACTION
# 1003       19680601                    H  KILLED IN ACTION
# 1020       19671001                   NH           ILLNESS
# 1053       19680201                    H    DIED OF WOUNDS
# 1082       19670601                    H  KILLED IN ACTION
# ...             ...                  ...               ...
# 56308      19710501                   NH           ILLNESS
# 56334      19710301                    H  KILLED IN ACTION
# 56420      19670101                    H  KILLED IN ACTION
# 56450      19680401                    H  KILLED IN ACTION
# 56476      19710201                   NH          ACCIDENT
# 56530      19651001                    H  KILLED IN ACTION
# 56537      19670301                    H  KILLED IN ACTION
# 56547      19661101                   NH          ACCIDENT
# 56550      19690101                   NH          ACCIDENT
# 56709      19670301                    H  KILLED IN ACTION
# 56777      19660601                    H  KILLED IN ACTION
# 56803      19860501                   NH          ACCIDENT
# 56881      19661001                    H  KILLED IN ACTION
# 57017      19740101                    H     DECLARED DEAD
# 57040      19671001                    H    DIED OF WOUNDS
# 57086      19680801                   NH          ACCIDENT
# 57217      19680501                    H  KILLED IN ACTION
# 57308      19680801                    H  KILLED IN ACTION
# 57588      19680401                    H  KILLED IN ACTION
# 57636      19680401                    H  KILLED IN ACTION
# 57680      19700301                   NH    SELF-INFLICTED
# 57689      19680101                    H  KILLED IN ACTION
# 57714      19670801                    H  KILLED IN ACTION
# 57853      19680501                    H  KILLED IN ACTION
# 57863      19780701                    H     DECLARED DEAD
# 58067      19660201                    H  KILLED IN ACTION
# 58082      19680101                    H  KILLED IN ACTION
# 58141      19680301                    H  KILLED IN ACTION
# 58147      19681101                    H    DIED OF WOUNDS
# 58159      19671001                   NH          ACCIDENT
#
#                                FATALITY_2 BURIAL_STATUS CASUALTIES_PER_CITY
# 13                         OTHER ACCIDENT             Y                 NaN
# 36                        SMALL ARMS FIRE             Y                 NaN
# 74                        SMALL ARMS FIRE             Y                 NaN
# 75                         OTHER ACCIDENT             Y                 NaN
# 128                               GRENADE             Y                 NaN
# 130         HELICOPTER CRASH -- CREW (MC)             Y                 NaN
# 159                       SMALL ARMS FIRE             Y                 NaN
# 327                       SMALL ARMS FIRE             Y                 NaN
# 334                       SMALL ARMS FIRE             Y                 NaN
# 363                        OTHER ACCIDENT             Y                 NaN
# 420                        OTHER ACCIDENT             Y                 NaN
# 487                       SMALL ARMS FIRE             Y                 NaN
# 588                        OTHER ACCIDENT             Y                 NaN
# 591                               GRENADE             Y                 NaN
# 593                               UNKNOWN             Y                 NaN
# 611                               GRENADE             Y                 NaN
# 613                               GRENADE             Y                 NaN
# 615                      EXPLOSIVE DEVICE             Y                 NaN
# 619         HELICOPTER CRASH -- CREW (MC)             Y                 NaN
# 663                      EXPLOSIVE DEVICE             Y                 NaN
# 792                      EXPLOSIVE DEVICE             Y                 NaN
# 827                       SMALL ARMS FIRE             Y                 NaN
# 831                       SMALL ARMS FIRE             Y                 NaN
# 864                               GRENADE             Y                 NaN
# 906                               UNKNOWN             Y                 NaN
# 966                       SMALL ARMS FIRE             Y                 NaN
# 1003                      SMALL ARMS FIRE             Y                 NaN
# 1020                   INFECTIOUS DISEASE             Y                 NaN
# 1053                              GRENADE             Y                 NaN
# 1082                              GRENADE             Y                 NaN
# ...                                   ...           ...                 ...
# 56308                              STROKE             Y                 NaN
# 56334                     SMALL ARMS FIRE             Y                 NaN
# 56420                             GRENADE             Y                 NaN
# 56450                            DROWNING             Y                 NaN
# 56476                  VEHICLE CRASH (MC)             Y                 NaN
# 56530                    EXPLOSIVE DEVICE             Y                 NaN
# 56537                     SMALL ARMS FIRE             Y                 NaN
# 56547                            DROWNING             Y                 NaN
# 56550  HELICOPTER CRASH -- PASSENGER (MC)             Y                 NaN
# 56709                     SMALL ARMS FIRE             Y                 NaN
# 56777                     SMALL ARMS FIRE             Y                 NaN
# 56803         AIRCRAFT CRASH -- CREW (MC)             Y                 NaN
# 56881                     SMALL ARMS FIRE             Y                 NaN
# 57017         AIRCRAFT CRASH -- CREW (MC)             N                 NaN
# 57040                     SMALL ARMS FIRE             Y                 NaN
# 57086                      OTHER ACCIDENT             Y                 NaN
# 57217                             GRENADE             Y                 NaN
# 57308                     SMALL ARMS FIRE             Y                 NaN
# 57588                    EXPLOSIVE DEVICE             Y                 NaN
# 57636                     SMALL ARMS FIRE             Y                 NaN
# 57680                             UNKNOWN             Y                 NaN
# 57689                     SMALL ARMS FIRE             Y                 NaN
# 57714                            DROWNING             Y                 NaN
# 57853                             GRENADE             Y                 NaN
# 57863                             UNKNOWN             N                 NaN
# 58067                     SMALL ARMS FIRE             Y                 NaN
# 58082                     SMALL ARMS FIRE             Y                 NaN
# 58141             ARTILLERY/MORTAR/ROCKET             Y                 NaN
# 58147                     SMALL ARMS FIRE             Y                 NaN
# 58159         AIRCRAFT CRASH -- CREW (MC)             N                 NaN
#
# [1370 rows x 32 columns]

# %%
whiteNYCasualty = data[(data["HOME_CITY"] == 'NEW YORK') & (data["ETHNICITY"] == 'WHITE')]
whiteNYCasualty.count()
# Out:
# SERVICE_TYPE               945
# SERVICE_CODE               945
# ENROLLMENT                 945
# BRANCH                     945
# RANK                       945
# PAY_GRADE                  945
# POSITION                   900
# BIRTH_YEAR                 945
# SEX                        945
# HOME_CITY                  945
# HOME_COUNTY                945
# NATIONALITY                945
# STATE_CODE                 945
# HOME_STATE                 945
# MARITAL_STATUS             945
# RELIGION                   945
# RELIGION_CODE              945
# ETHNICITY                  945
# ETHNICITY_1                945
# ETHNICITY_2                945
# DEPLOYMENT_PROVINCE        812
# DEPLOYMENT_ZONE            810
# DEPLOYMENT_COUNTRY_CODE    945
# DEPLOYMENT_COUNTRY         945
# DIVISION                   702
# FATALITY_YEAR              945
# FATALITY_DATE              945
# HOSTILITY_CONDITIONS       945
# FATALITY                   945
# FATALITY_2                 945
# BURIAL_STATUS              945
# CASUALTIES_PER_CITY          0
# dtype: int64

# %%
# Black casualty count
blackCasualty = data[ethnicity == "BLACK OR AFRICAN AMERICAN"]
blackCasualty["ETHNICITY"].count()
# Out:
# 7267
